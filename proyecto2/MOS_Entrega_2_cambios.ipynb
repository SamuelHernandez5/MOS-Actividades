# %% [markdown]
# # **Proyecto MOS - Etapa 2**

# %%
import sys
if "google.colab" in sys.modules:
    # !wget "https://raw.githubusercontent.com/ndcbe/CBE60499/main/notebooks/helper.py"
    import helper
    helper.install_idaes()
    helper.install_glpk()
    helper.install_ipopt()

from pyomo.environ import *
from haversine import haversine
import pandas as pd
import requests

import folium
import sympy as sp
import numpy as np
import pandas as pd
import seaborn as sns
import networkx as nx
from amplpy import modules
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Modelo Matemático**

# %% [markdown]
# ### **Suposiciones**
# * La demanda de los clientes y la capacidad de los centros de distribución estan en las mismas unidades.
# * Para los casos a resolver, los nodos no están concentrados en un único sector.
# * Los vehículos deben cargar inventario desde algún centro de distribución al comenzar la jornada y deben regresar a algún centro de distribución al finalizarla.

# %% [markdown]
# ### **Conjuntos**
# * $C$: Conjunto de clientes.
# * $D$: Conjunto de centros de distribución.
# * $V$: Conjunto de vehículos.
# * $A \subseteq (C \cup D) \times (C \cup D)$: Conjunto de arcos posibles entre nodos.

# %% [markdown]
# ### **Parámetros**
# * $cap_d$: Capacidad máxima del centro de distribución $d \in D$.
# * $cap_v$: Capacidad útil de carga del vehículo $v \in V$.
# * $rang_v$: Rango útil (en km) del vehículo $v \in V$.
# * $dem_c$: Demanda del cliente $c \in C$.
# * $dist_{ij}$: Distancia entre nodo $i$ y nodo $j$, para $(i,j) \in A$.
# * $Pf$: Precio del combustible por litro (COP/l).
# * $Ft$: Tarifa de flete por kilómetro recorrido (COP/km).
# * $Cm$: Costo de mantenimiento por kilómetro recorrido (COP/km).
# * $RC$: Rendimiento del combustible (l/km)

# %% [markdown]
# ### **Variables de decisión**
# * $x_{ijv} \in \{0,1\}$: 1 si el vehículo $v$ recorre el arco $(i,j)$, 0 en caso contrario.
# * $u_{iv} \leq |(C \cup D)| - 1$: Variable auxiliar para la prevencion de sub-tours.

# %% [markdown]
# ### **Función objetivo**
# Minimizar el costo total de operación
#
# $$\min \sum_{v \in V} \sum_{(i,j) \in A} x_{ijv} \cdot dist_{ij} \cdot (Ft + Cm + (RC \cdot Pf))$$

# %% [markdown]
# ### **Restricciones**
#
# Capacidad de centros de distribución:
# * $\sum_{i \in C} \sum_{v \in V} x_{div}\cdot dem_c \leq cap_d \quad \forall d \in D$
#
# Capacidad de vehículos:
# * $\sum_{(i, c) \in A} x_{icv}\cdot dem_{c} \leq cap_v \quad \forall v \in V\  | \ c \in C$
#
# Todos los clientes deben ser visitados:
# * $\sum_{v \in V}\sum_{i \in C U D} x_{icv} = 1 \quad \forall c \in C$
#
# Autonomía de vehículos:
# * $\sum_{(i,j) \in A} dist_{ij} \cdot x_{ijv} \leq rang_v \quad \forall v \in V$
#
# Un solo vehículo por salida de centro de distribucion:
# * $\sum_{c \in C} \sum_{d \in D} x_{dcv} \leq 1, \forall v \in V$
#
# Conservación del flujo para los nodos intermedios(flujo balanceado por nodo):
# * $\sum_{j: (i,j) \in A} x_{ijv} - \sum_{j: (j,i) \in A} x_{jiv} = 0 \quad \forall i \in C, \forall v \in V$
#
# Un solo vehículo por llegada al centro de distribucion:
# * $\sum_{c \in C} \sum_{d \in D} x_{cdv} \leq 1, \forall v \in V$
#
# Eliminación de Sub-Tours:
# * $u_{iv} - u_{jv} + |(C \cup D)| \cdot x_{ijv} \leq |(C \cup D)| - 1 \quad \forall i,j \in C, v \in V, i \neq j\quad$
#
# Llegada de cada vehículo a un único centro de distribución:
# * $\sum_{c \in C} \sum_{d \in D} x_{cdv} \geq 1, \forall v \in V$

# %% [markdown]
# ## **Procesamiento de Datos**

# %%
vehicles1 = pd.read_csv('data/caso1/vehicles.csv')
vehicles1
# Out:
#    VehicleID  Capacity  Range
# 0          1       130    170
# 1          2       140    200
# 2          3       120    180
# 3          4       100     90
# 4          5        70    100
# 5          6        55    170
# 6          7       110    150
# 7          8       114    140

# %%
clients1 = pd.read_csv('data/caso1/clients.csv')
clients1
# Out:
#     ClientID  LocationID  Demand  Longitude  Latitude
# 0          1           2      13 -74.098938  4.597954
# 1          2           3      15 -74.075571  4.687821
# 2          3           4      12 -74.107085  4.709494
# 3          4           5      15 -74.097280  4.605029
# 4          5           6      20 -74.164641  4.648464
# 5          6           7      17 -74.120838  4.662137
# 6          7           8      17 -74.022131  4.697499
# 7          8           9      20 -74.172075  4.649417
# 8          9          10      20 -74.156153  4.606311
# 9         10          11      15 -74.090411  4.557380
# 10        11          12      17 -74.178023  4.591594
# 11        12          13      12 -74.101541  4.756417
# 12        13          14      21 -74.096909  4.646217
# 13        14          15      15 -74.121920  4.725912
# 14        15          16      17 -74.094295  4.604168
# 15        16          17      10 -74.111388  4.557321
# 16        17          18      25 -74.124639  4.615869
# 17        18          19      12 -74.124562  4.656403
# 18        19          20      11 -74.049906  4.706188
# 19        20          21      15 -74.121867  4.746625
# 20        21          22      14 -74.024549  4.746517
# 21        22          23      18 -74.086836  4.625426
# 22        23          24      15 -74.116526  4.731407
# 23        24          25      11 -74.126293  4.577490

# %%
depots1 = pd.read_csv('data/caso1/depots.csv')
depots1
# Out:
#    LocationID    DepotID  Longitude  Latitude
# 0           1 -74.153536   4.743359       NaN

# %% [markdown]
# ## **Modelo en Pyomo**

# %%
import sys
if "google.colab" in sys.modules:
    # !wget "https://raw.githubusercontent.com/ndcbe/CBE60499/main/notebooks/helper.py"
    import helper
    helper.install_idaes()
    helper.install_glpk()
    helper.install_ipopt()

centros = {
    "CD1": {"lat": 4.7110, "lon": -74.0721, "cap": 20000},
    "CD2": {"lat": 4.6050, "lon": -74.0835, "cap": 50000},
    "CD3": {"lat": 4.6700, "lon": -74.0300, "cap": 30000}
}

clientes = {
    "C1": {"lat": 4.6486, "lon": -74.0608, "demanda": 50},
    "C2": {"lat": 4.7333, "lon": -74.0700, "demanda": 80},
    "C3": {"lat": 4.7000, "lon": -74.0200, "demanda": 65}
}

vehiculos = {
    "V1": {"cap": 100, "rango": 120},
    "V2": {"cap": 80, "rango": 100},
    "V3": {"cap": 150, "rango": 150}
}

parametros = {"Pf": 15000, "Ft": 5000, "Cm": 700, "RC": 0.35}

#Usa la API de OSRM (Open Source Routing Machine)
def get_route_info(lat1, lon1, lat2, lon2):
    base_url = "http://router.project-osrm.org/route/v1/driving/"
    coordinates = f"{lon1},{lat1};{lon2},{lat2}"
    url = base_url + coordinates
    params = {
        "overview": "full",
        "geometries": "geojson"
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        if "routes" in data and data["routes"]:
            route = data["routes"][0]
            distance = route["distance"] / 1000.0
            geometry = route["geometry"]["coordinates"]
            polyline = [[coord[1], coord[0]] for coord in geometry]
            return distance, polyline
        else:
            raise Exception("No se encontró una ruta.")
    except Exception as e:
        print("Error al obtener ruta vía OSRM:", e)
        fallback_distance = haversine((lat1, lon1), (lat2, lon2))
        fallback_polyline = [[lat1, lon1], [lat2, lon2]]
        return fallback_distance, fallback_polyline

all_nodes = list(centros.keys()) + list(clientes.keys())
distancias = {}
geometries = {}

for i in all_nodes:
    for j in all_nodes:
        if i != j and not (i in centros and j in centros):
            if i in centros:
                lat_i, lon_i = centros[i]["lat"], centros[i]["lon"]
            else:
                lat_i, lon_i = clientes[i]["lat"], clientes[i]["lon"]
            if j in centros:
                lat_j, lon_j = centros[j]["lat"], centros[j]["lon"]
            else:
                lat_j, lon_j = clientes[j]["lat"], clientes[j]["lon"]
            d, polyline = get_route_info(lat_i, lon_i, lat_j, lon_j)
            distancias[(i, j)] = d
            geometries[(i, j)] = polyline

print(pd.DataFrame.from_dict(distancias, orient="index", columns=["Distancia (km)"]))

model = ConcreteModel()

# Conjuntos
model.C = Set(initialize=clientes.keys())
model.D = Set(initialize=centros.keys())
model.V = Set(initialize=vehiculos.keys())
model.A = Set(
    within=(model.D | model.C) * (model.D | model.C),
    initialize=[(i, j) for i in (set(centros.keys()) | set(clientes.keys()))
                for j in (set(centros.keys()) | set(clientes.keys()))
                if i != j and not (i in centros and j in centros)]
)

# Parámetros
model.dem_c = Param(model.C, initialize={c: clientes[c]["demanda"] for c in clientes})
model.dist_ij = Param(model.A, initialize=distancias)
model.cap_v = Param(model.V, initialize={v: vehiculos[v]["cap"] for v in vehiculos})
model.rang_v = Param(model.V, initialize={v: vehiculos[v]["rango"] for v in vehiculos})
model.cap_d = Param(model.D, initialize={d: centros[d]["cap"] for d in centros})

# Variables
model.x = Var(model.A, model.V, within=Binary)
model.u = Var(model.C, model.V, within=NonNegativeIntegers,
              bounds=(0, (len(model.C | model.D) - 1)))

# Función objetivo
def funcion_objetivo(model):
    return sum(model.x[i, j, v] * model.dist_ij[i, j] * (parametros["Ft"] + parametros["Cm"] + (parametros["RC"] * parametros["Pf"]))
               for v in model.V
               for (i, j) in model.A)
model.objetivo = Objective(rule=funcion_objetivo, sense=minimize)

# Restricciones

# 1. Capacidad de centros de distribución
def capacidad_distribucion_rule(model, d):
    return sum(model.x[d, c, v] * model.dem_c[c] for c in model.C for v in model.V) <= model.cap_d[d]
model.capacidad_distribucion = Constraint(model.D, rule=capacidad_distribucion_rule)

# 2. Capacidad de vehículos
def capacidad_vehiculos_rule(model, v):
    return sum(model.x[i, c, v] * model.dem_c[c] for (i, c) in model.A if c in model.C) <= model.cap_v[v]
model.capacidad_vehiculos = Constraint(model.V, rule=capacidad_vehiculos_rule)

# 3. Todos los clientes deben ser visitados
def visitar_clientes_rule(model, c):
    return sum(model.x[i, c, v] for v in model.V for i in (set(centros.keys()) | set(clientes.keys())) if (i, c) in model.A) == 1
model.visitar_clientes = Constraint(model.C, rule=visitar_clientes_rule)

# 4. Autonomía de vehículos
def autonomia_vehiculos_rule(model, v):
    return sum(model.dist_ij[i, j] * model.x[i, j, v] for (i, j) in model.A) <= model.rang_v[v]
model.autonomia_vehiculos = Constraint(model.V, rule=autonomia_vehiculos_rule)

# 5. Conservación del flujo
def conservacion_flujo_rule(model, i, v):
    nodos = set(centros.keys()) | set(clientes.keys())
    salida = sum(model.x[i, j, v] for j in nodos if (i, j) in model.A)
    entrada = sum(model.x[j, i, v] for j in nodos if (j, i) in model.A)
    return salida - entrada == 0 if i in model.C else salida - entrada <= 1
model.conservacion_flujo = Constraint((set(centros.keys()) | set(clientes.keys())), model.V, rule=conservacion_flujo_rule)

# 6. Eliminación de subrutas (subtours)
def subtours_elimination_rule(model, i, j, v):
    if i != j and i in model.C and j in model.C:
        return model.u[i, v] - model.u[j, v] + (len(set(centros.keys()) | set(clientes.keys()))) * model.x[i, j, v] <= (len(set(centros.keys()) | set(clientes.keys())) - 1)
    else:
        return Constraint.Skip
model.subtours_elimination = Constraint(model.C, model.C, model.V, rule=subtours_elimination_rule)

# Restricción de salida inicial: cada vehículo sale de algún centro hacia un cliente
def salida_unica_rule(model, v):
    return sum(model.x[d, j, v] for d in model.D for j in model.C if (d, j) in model.A) == 1
model.salida_unica = Constraint(model.V, rule=salida_unica_rule)

# Restricción de retorno: cada vehículo debe retornar a un centro
def retorno_centro_rule(model, v):
    return sum(model.x[i, d, v] for d in model.D for i in model.C if (i, d) in model.A) >= 1
model.retorno_centro = Constraint(model.V, rule=retorno_centro_rule)


solver = SolverFactory('glpk')
results = solver.solve(model, tee=True)

print("Asignaciones por vehículo:")
for v in model.V:
    print(f"\nVehículo {v}:")
    for (i, j) in model.A:
        if model.x[i, j, v].value is not None and model.x[i, j, v].value == 1:
            print(f"  - {i} -> {j}")


#Visualización
import folium

all_coords = [(centros[n]["lat"], centros[n]["lon"]) for n in centros] + [(clientes[n]["lat"], clientes[n]["lon"]) for n in clientes]
mean_lat = sum([lat for lat, lon in all_coords]) / len(all_coords)
mean_lon = sum([lon for lat, lon in all_coords]) / len(all_coords)

m = folium.Map(location=[mean_lat, mean_lon], zoom_start=13)

for cd in centros:
    folium.Marker(
        location=[centros[cd]["lat"], centros[cd]["lon"]],
        popup=f"Centro {cd}",
        icon=folium.Icon(color='green', icon='home', prefix='fa')
    ).add_to(m)

for c in clientes:
    folium.Marker(
        location=[clientes[c]["lat"], clientes[c]["lon"]],
        popup=f"Cliente {c}",
        icon=folium.Icon(color='blue', icon='user', prefix='fa')
    ).add_to(m)

vehicle_colors = {'V1': 'red', 'V2': 'orange', 'V3': 'purple'}

for v in model.V:
    for (i, j) in model.A:
        if model.x[i, j, v].value is not None and model.x[i, j, v].value == 1:
            polyline = geometries.get((i, j))
            if polyline:
                folium.PolyLine(
                    locations=polyline,
                    color=vehicle_colors.get(v, 'black'),
                    weight=5,
                    opacity=0.8,
                    popup=f"Ruta {i} -> {j} (Vehículo {v})"
                ).add_to(m)


m.save("resultados/mapa_caso_1.html")
print("El mapa de rutas ha sido guardado en 'ruta_optima_folium.html'.")
# Out:
#            Distancia (km)
# (CD1, C1)          9.4502
# (CD1, C2)          4.4471
# (CD1, C3)          7.4524
# (CD2, C1)          7.4304
# (CD2, C2)         17.7584
# (CD2, C3)         17.2551
# (CD3, C1)          8.7941
# (CD3, C2)         16.2244
# (CD3, C3)         12.7021
# (C1, CD1)         10.0317
# (C1, CD2)          6.7716
# (C1, CD3)          8.4747
# (C1, C2)          12.3424
# (C1, C3)           9.7215
# (C2, CD1)          3.7279
# (C2, CD2)         17.9546
# (C2, CD3)         17.4386
# (C2, C1)          12.1142
# (C2, C3)          10.5682
# (C3, CD1)          8.6026
# (C3, CD2)         19.7141
# (C3, CD3)         14.5220
# (C3, C1)          10.4619
# (C3, C2)          10.7491
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write C:\Users\57313\AppData\Local\Temp\tmpgxf7um7_.glpk.raw --wglp C:\Users\57313\AppData\Local\Temp\tmppa72jwds.glpk.glp
#  --cpxlp C:\Users\57313\AppData\Local\Temp\tmpgwcs3ci3.pyomo.lp
# Reading problem data from 'C:\Users\57313\AppData\Local\Temp\tmpgwcs3ci3.pyomo.lp'...
# C:\Users\57313\AppData\Local\Temp\tmpgwcs3ci3.pyomo.lp:776: warning: lower bound of variable 'x2' redefined
# C:\Users\57313\AppData\Local\Temp\tmpgwcs3ci3.pyomo.lp:776: warning: upper bound of variable 'x2' redefined
# 54 rows, 81 columns, 441 non-zeros
# 81 integer variables, 72 of which are binary
# 848 lines were read
# Writing problem data to 'C:\Users\57313\AppData\Local\Temp\tmppa72jwds.glpk.glp'...
# 705 lines were written
# GLPK Integer Optimizer 5.0
# 54 rows, 81 columns, 441 non-zeros
# 81 integer variables, 72 of which are binary
# Preprocessing...
# 1 hidden packing inequaliti(es) were detected
# 51 rows, 81 columns, 414 non-zeros
# 81 integer variables, 72 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  8.000e+01  ratio =  8.000e+01
# GM: min|aij| =  6.449e-01  max|aij| =  1.551e+00  ratio =  2.404e+00
# EQ: min|aij| =  4.199e-01  max|aij| =  1.000e+00  ratio =  2.382e+00
# 2N: min|aij| =  2.330e-01  max|aij| =  1.500e+00  ratio =  6.438e+00
# Constructing initial basis...
# Size of triangular part is 51
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 51 rows, 81 columns, 414 non-zeros
#       0: obj =   9.155284050e+05 inf =   5.125e+00 (5)
#       2: obj =   8.408745900e+05 inf =   1.332e-15 (0)
# *    28: obj =   4.208304000e+05 inf =   6.106e-16 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    28: mip =     not found yet >=              -inf        (1; 0)
# +    28: >>>>>   4.208304000e+05 >=   4.208304000e+05   0.0% (1; 0)
# +    28: mip =   4.208304000e+05 >=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (185621 bytes)
# Writing MIP solution to 'C:\Users\57313\AppData\Local\Temp\tmpgxf7um7_.glpk.raw'...
# 144 lines were written
# Asignaciones por vehículo:
#
# Vehículo V1:
#   - C1 -> CD2
#   - CD2 -> C1
#
# Vehículo V2:
#   - CD1 -> C2
#   - C2 -> CD1
#
# Vehículo V3:
#   - CD1 -> C3
#   - C3 -> CD1
# El mapa de rutas ha sido guardado en 'ruta_optima_folium.html'.

# %% [markdown]
# ## **Caso 1: CVRP Estándar**

# %%
depot = depots1.iloc[0]
centros = {
    "CD1": {
        "lat": depot["Longitude"],
        "lon": depot["DepotID"],     #ERROR ID
        "cap": 40000
    }
}

centros
# Out:
# {'CD1': {'lat': np.float64(4.743359),
#   'lon': np.float64(-74.153536),
#   'cap': 40000}}

# %%
base_cap = vehicles1.iloc[0]["Capacity"]
base_rang = vehicles1.iloc[0]["Range"]

vehiculos = {f"V{v}": {"cap": base_cap, "rango": base_rang}
             for v in vehicles1["VehicleID"]}

vehiculos
# Out:
# {'V1': {'cap': np.int64(130), 'rango': np.int64(170)},
#  'V2': {'cap': np.int64(130), 'rango': np.int64(170)},
#  'V3': {'cap': np.int64(130), 'rango': np.int64(170)},
#  'V4': {'cap': np.int64(130), 'rango': np.int64(170)},
#  'V5': {'cap': np.int64(130), 'rango': np.int64(170)},
#  'V6': {'cap': np.int64(130), 'rango': np.int64(170)},
#  'V7': {'cap': np.int64(130), 'rango': np.int64(170)},
#  'V8': {'cap': np.int64(130), 'rango': np.int64(170)}}

# %%
clientes = {
    row["ClientID"]: {"lat": row["Latitude"], "lon": row["Longitude"], "demanda": row["Demand"]}
    for _, row in clients1.iterrows()
}
clientes
# Out:
# {np.float64(1.0): {'lat': np.float64(4.59795431125545),
#   'lon': np.float64(-74.09893796560621),
#   'demanda': np.float64(13.0)},
#  np.float64(2.0): {'lat': np.float64(4.687820646838871),
#   'lon': np.float64(-74.07557103763986),
#   'demanda': np.float64(15.0)},
#  np.float64(3.0): {'lat': np.float64(4.70949446000624),
#   'lon': np.float64(-74.10708524062704),
#   'demanda': np.float64(12.0)},
#  np.float64(4.0): {'lat': np.float64(4.605029068682624),
#   'lon': np.float64(-74.09727965657427),
#   'demanda': np.float64(15.0)},
#  np.float64(5.0): {'lat': np.float64(4.648463876533332),
#   'lon': np.float64(-74.16464148202755),
#   'demanda': np.float64(20.0)},
#  np.float64(6.0): {'lat': np.float64(4.662137416953968),
#   'lon': np.float64(-74.12083799988112),
#   'demanda': np.float64(17.0)},
#  np.float64(7.0): {'lat': np.float64(4.697499030379109),
#   'lon': np.float64(-74.02213076607309),
#   'demanda': np.float64(17.0)},
#  np.float64(8.0): {'lat': np.float64(4.649416884236942),
#   'lon': np.float64(-74.17207549744595),
#   'demanda': np.float64(20.0)},
#  np.float64(9.0): {'lat': np.float64(4.606310650273935),
#   'lon': np.float64(-74.15615257246444),
#   'demanda': np.float64(20.0)},
#  np.float64(10.0): {'lat': np.float64(4.557379705282216),
#   'lon': np.float64(-74.09041145358674),
#   'demanda': np.float64(15.0)},
#  np.float64(11.0): {'lat': np.float64(4.591594072172954),
#   'lon': np.float64(-74.17802255204528),
#   'demanda': np.float64(17.0)},
#  np.float64(12.0): {'lat': np.float64(4.7564172406324055),
#   'lon': np.float64(-74.1015410917749),
#   'demanda': np.float64(12.0)},
#  np.float64(13.0): {'lat': np.float64(4.646217006050524),
#   'lon': np.float64(-74.09690889182339),
#   'demanda': np.float64(21.0)},
#  np.float64(14.0): {'lat': np.float64(4.725912125314368),
#   'lon': np.float64(-74.1219200708342),
#   'demanda': np.float64(15.0)},
#  np.float64(15.0): {'lat': np.float64(4.604168478560718),
#   'lon': np.float64(-74.0942948461378),
#   'demanda': np.float64(17.0)},
#  np.float64(16.0): {'lat': np.float64(4.557320898243896),
#   'lon': np.float64(-74.11138839002187),
#   'demanda': np.float64(10.0)},
#  np.float64(17.0): {'lat': np.float64(4.615869066082658),
#   'lon': np.float64(-74.12463941285208),
#   'demanda': np.float64(25.0)},
#  np.float64(18.0): {'lat': np.float64(4.656402930181292),
#   'lon': np.float64(-74.12456164551857),
#   'demanda': np.float64(12.0)},
#  np.float64(19.0): {'lat': np.float64(4.706188309535041),
#   'lon': np.float64(-74.04990580408855),
#   'demanda': np.float64(11.0)},
#  np.float64(20.0): {'lat': np.float64(4.746624762561149),
#   'lon': np.float64(-74.121866801394),
#   'demanda': np.float64(15.0)},
#  np.float64(21.0): {'lat': np.float64(4.746517184687941),
#   'lon': np.float64(-74.02454895778163),
#   'demanda': np.float64(14.0)},
#  np.float64(22.0): {'lat': np.float64(4.625425626584072),
#   'lon': np.float64(-74.08683592702927),
#   'demanda': np.float64(18.0)},
#  np.float64(23.0): {'lat': np.float64(4.731406773645735),
#   'lon': np.float64(-74.11652648751144),
#   'demanda': np.float64(15.0)},
#  np.float64(24.0): {'lat': np.float64(4.577489966973782),
#   'lon': np.float64(-74.12629327283491),
#   'demanda': np.float64(11.0)}}

# %% [markdown]
# ## **Caso 2: Múltiples Centros de Distribución**
#
# ## **Procesamiento de Datos**

# %%
import pandas as pd

vehicles = pd.read_csv('data/caso2/vehicles.csv')
depots = pd.read_csv('data/caso2/depots.csv')
clients = pd.read_csv('data/caso2/clients.csv')

depot_ids   = depots['DepotID'].tolist()
client_ids  = clients['ClientID'].tolist()
vehicle_ids = vehicles['VehicleID'].tolist()

# Hallar las distancias entre los nodos

distance_matrix_file = 'data/caso2/distance_matrix.csv'
distance_matrix = {}

# Intentar cargar desde CSV (ahora con DepotID y ClientID como índices)
try:
    pd.read_csv("nohay")
    #df_dist = pd.read_csv(distance_matrix_file, index_col=['DepotID','ClientID'])
    # df_dist debe tener columnas: Distancia (km)
    #distance_matrix = df_dist['Distancia (km)'].to_dict()
    #print("Distancias cargadas desde el CSV.")
except FileNotFoundError:
    # Si no existe, calcular y guardar
    for _, depot in depots.iterrows():
        d_id = depot['DepotID']
        lat_d, lon_d = depot['Latitude'], depot['Longitude']
        for _, client in clients.iterrows():
            c_id = client['ClientID']
            lat_c, lon_c = client['Latitude'], client['Longitude']
            
            # Obtener distancia usando OSRM
            dist, _ = get_route_info(lat_d, lon_d, lat_c, lon_c)
            distance_matrix[(int(d_id), int(c_id))] = dist

    # Guardar en CSV con índices DepotID y ClientID
    df_out = pd.DataFrame.from_dict(
        distance_matrix, 
        orient='index', 
        columns=['Distancia (km)']
    )
    df_out.index.set_names(['DepotID','ClientID'], inplace=True)
    df_out.to_csv(distance_matrix_file)
    print("Distancias calculadas y guardadas en CSV.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[98], line 18
#      17 try:
# ---> 18     pd.read_csv("nohay")
#      19     #df_dist = pd.read_csv(distance_matrix_file, index_col=['DepotID','ClientID'])
#      20     # df_dist debe tener columnas: Distancia (km)
#      21     #distance_matrix = df_dist['Distancia (km)'].to_dict()
#      22     #print("Distancias cargadas desde el CSV.")
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871 if ioargs.encoding and "b" not in ioargs.mode:
#     872     # Encoding
# --> 873     handle = open(
#     874         handle,
#     875         ioargs.mode,
#     876         encoding=ioargs.encoding,
#     877         errors=errors,
#     878         newline="",
#     879     )
#     880 else:
#     881     # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nohay'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 42
#      36 # Guardar en CSV con índices DepotID y ClientID
#      37 df_out = pd.DataFrame.from_dict(
#      38     distance_matrix,
#      39     orient='index',
#      40     columns=['Distancia (km)']
#      41 )
# ---> 42 df_out.index.set_names(['DepotID','ClientID'], inplace=True)
#      43 df_out.to_csv(distance_matrix_file)
#      44 print("Distancias calculadas y guardadas en CSV.")
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pandas\core\indexes\base.py:1909, in Index.set_names(self, names, level, inplace)
#    1906 else:
#    1907     idx = self._view()
# -> 1909 idx._set_names(names, level=level)
#    1910 if not inplace:
#    1911     return idx
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pandas\core\indexes\base.py:1787, in Index._set_names(self, values, level)
#    1785     raise ValueError("Names must be a list-like")
#    1786 if len(values) != 1:
# -> 1787     raise ValueError(f"Length of new names must be 1, got {len(values)}")
#    1789 # GH 20527
#    1790 # All items in 'name' need to be hashable:
#    1791 validate_all_hashable(*values, error_name=f"{type(self).__name__}.name")
#
# ValueError: Length of new names must be 1, got 2

# %%
from pyomo.environ import *

# Crear el modelo
model = ConcreteModel()

# Conjuntos

model.D = Set(initialize=depot_ids)    # Centros de distribución
model.C = Set(initialize=client_ids)   # Clientes
model.V = Set(initialize=vehicle_ids)  # Vehículos

nodes = depot_ids + client_ids

model.A = Set(
    dimen=2,
    initialize=[ 
        (i, j) for i in nodes for j in nodes 
        if i != j and not (i in depot_ids and j in depot_ids)
    ]
)

# Parámetros

model.dist = Param(model.A, initialize=distance_matrix)

model.dem_c = Param(model.C, initialize=clients.set_index('ClientID')['Demand'].to_dict())
model.cap_v = Param(model.V, initialize=vehicles.set_index('VehicleID')['Capacity'].to_dict())
model.cap_d = Param(model.D, initialize=depots.set_index('DepotID')['Capacity'].to_dict())
model.range_v = Param(model.V, initialize=vehicles.set_index('VehicleID')['Range'].to_dict())

# Variables de decisión
model.x = Var(model.D, model.C, model.V, domain=Binary)  # Asignación de vehículos a clientes
model.u = Var(model.C, model.V, domain=NonNegativeIntegers)  # Preventión de sub-tours

# Restricciones

# 1. Capacidad centros
def capacidad_distribucion_rule(m, d):
    return sum(m.x[d,c,v] * m.dem_c[c]
               for c in m.C for v in m.V) <= m.capd[d]
model.capacidad_distribucion = Constraint(model.D, rule=capacidad_distribucion_rule)

# 2. Capacidad vehículos
def capacidad_vehiculos_rule(m, v):
    return sum(m.x[i,c,v] * m.dem_c[c]
               for (i,c) in m.A) <= m.capv[v]
model.capacidad_vehiculos = Constraint(model.V, rule=capacidad_vehiculos_rule)

# 3. Visitar todos los clientes
def visitar_clientes_rule(m, c):
    return sum(m.x[i,c,v] for (i,c2) in m.A if c2==c for v in m.V) == 1
model.visitar_clientes = Constraint(model.C, rule=visitar_clientes_rule)

# 4. Autonomía de vehículos
def autonomia_vehiculos_rule(m, v):
    return sum(m.dist_ij[i,j] * m.x[i,j,v] for (i,j) in m.A) <= m.range_v[v]
model.autonomia_vehiculos = Constraint(model.V, rule=autonomia_vehiculos_rule)

# 5. Conservación de flujo
def conservacion_flujo_rule(m, i, v):
    # solo definimos para i en clientes
    if i in m.C:
        out_ = sum(m.x[i,j,v] for (i2,j) in m.A if i2==i)
        in_  = sum(m.x[j,i,v] for (j,i2) in m.A if i2==i)
        return out_ - in_ == 0
    else:
        return Constraint.Skip
model.conservacion_flujo = Constraint(model.C, model.V, rule=conservacion_flujo_rule)

# 6. Eliminación de subrutas (MTZ)
def subtours_elimination_rule(m, i, j, v):
    if i!=j and i in m.C and j in m.C:
        N = len(m.C|m.D)
        return m.u[i,v] - m.u[j,v] + N*m.x[i,j,v] <= N-1
    else:
        return Constraint.Skip
model.subtours_elimination = Constraint(model.C, model.C, model.V,
                                        rule=subtours_elimination_rule)

# 7. Salida inicial única (D→C)
def salida_unica_rule(m, v):
    return sum(m.x[d,c,v] for d in m.D for c in m.C) == 1
model.salida_unica = Constraint(model.V, rule=salida_unica_rule)

# 8. Retorno a algún centro (C→D)
def retorno_centro_rule(m, v):
    return sum(m.x[c,d,v] for d in m.D for c in m.C) >= 1
model.retorno_centro = Constraint(model.V, rule=retorno_centro_rule)
# Función objetivo: minimizar el costo de operación
def objective_rule(model):
    return sum(model.x[d, c, v] * model.dist[d, c] * (parametros["Ft"] + parametros["Cm"] + (parametros["RC"] * parametros["Pf"]))
               for d in model.D for c in model.C for v in model.V)

model.obj = Objective(rule=objective_rule, sense=minimize)
# Out:
# ERROR: Rule failed for Param 'dist' with index (1, 1): KeyError: "Index '(1,
# 1)' is not valid for indexed component 'dist'"
# ERROR: Constructing component 'dist' from data=None failed:
#         KeyError: "Index '(1, 1)' is not valid for indexed component 'dist'"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 24
#      14 model.A = Set(
#      15     dimen=2,
#      16     initialize=[
#    (...)
#      19     ]
#      20 )
#      22 # Parámetros
# ---> 24 model.dist = Param(model.A, initialize=distance_matrix)
#      26 model.dem_c = Param(model.C, initialize=clients.set_index('ClientID')['Demand'].to_dict())
#      27 model.cap_v = Param(model.V, initialize=vehicles.set_index('VehicleID')['Capacity'].to_dict())
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pyomo\core\base\block.py:571, in BlockData.__setattr__(self, name, val)
#     566 if name not in self.__dict__:
#     567     if isinstance(val, Component):
#     568         #
#     569         # Pyomo components are added with the add_component method.
#     570         #
# --> 571         self.add_component(name, val)
#     572     else:
#     573         #
#     574         # Other Python objects are added with the standard __setattr__
#     575         # method.
#     576         #
#     577         super(BlockData, self).__setattr__(name, val)
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pyomo\core\base\block.py:1105, in BlockData.add_component(self, name, val)
#    1097     logger.debug(
#    1098         "Constructing %s '%s' on %s from data=%s",
#    1099         val.__class__.__name__,
#    (...)
#    1102         str(data),
#    1103     )
#    1104 try:
# -> 1105     val.construct(data)
#    1106 except:
#    1107     err = sys.exc_info()[1]
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pyomo\core\base\param.py:847, in Param.construct(self, data)
#     843 self._constructed = None
#     844 #
#     845 # Step #1: initialize data from rule value
#     846 #
# --> 847 self._construct_from_rule_using_setitem()
#     848 #
#     849 # Step #2: allow any user-specified (external) data to override
#     850 # the initialization
#     851 #
#     852 if data is not None:
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pyomo\core\base\indexed_component.py:772, in IndexedComponent._construct_from_rule_using_setitem(self)
#     769 if rule.contains_indices():
#     770     # The index is coming in externally; we need to validate it
#     771     for index in rule.indices():
# --> 772         self[index] = rule(block, index)
#     773 elif not self.index_set().isfinite():
#     774     # If the index is not finite, then we cannot iterate
#     775     # over it.  Since the rule doesn't provide explicit
#     776     # indices, then there is nothing we can do (the
#     777     # assumption is that the user will trigger specific
#     778     # indices to be created at a later time).
#     779     pass
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pyomo\core\base\indexed_component.py:692, in IndexedComponent.__setitem__(self, index, val)
#     687 if obj is _NotFound:
#     688     # If we didn't find the index in the data, then we need to
#     689     # validate it against the underlying set (as long as
#     690     # _processUnhashableIndex didn't return a slicer)
#     691     if index.__class__ is not IndexedComponent_slice:
# --> 692         index = self._validate_index(index)
#     693 else:
#     694     return self._setitem_impl(index, obj, val)
#
# File c:\Users\57313\anaconda3\envs\pyomo_env\lib\site-packages\pyomo\core\base\indexed_component.py:870, in IndexedComponent._validate_index(self, idx)
#     863     raise KeyError(
#     864         "Cannot treat the scalar component '%s' "
#     865         "as an indexed component" % (self.name,)
#     866     )
#     867 #
#     868 # Raise an exception
#     869 #
# --> 870 raise KeyError(
#     871     "Index '%s' is not valid for indexed component '%s'"
#     872     % (normalized_idx, self.name)
#     873 )
#
# KeyError: "Index '(1, 1)' is not valid for indexed component 'dist'"

# %%
distance_matrix
# Out:
# {(1, 1): 22.414900000000003, (1, 2): 25.897, (1, 3): 4.2255, (1, 4): 22.3388, (1, 5): 12.0648, (1, 6): 18.0886, (1, 7): 19.57, (1, 8): 10.4852, (1, 9): 18.5532, (2, 1): 20.1792, (2, 2): 15.0952, (2, 3): 32.5322, (2, 4): 21.842299999999998, (2, 5): 30.8034, (2, 6): 23.599400000000003, (2, 7): 25.0958, (2, 8): 29.2194, (2, 9): 16.821900000000003, (3, 1): 35.8031, (3, 2): 34.588300000000004, (3, 3): 18.412599999999998, (3, 4): 35.7271, (3, 5): 25.6175, (3, 6): 31.4769, (3, 7): 23.4015, (3, 8): 16.1367, (3, 9): 28.955, (4, 1): 21.4009, (4, 2): 20.3548, (4, 3): 6.308, (4, 4): 21.3248, (4, 5): 11.0046, (4, 6): 17.0746, (4, 7): 13.4457, (4, 8): 3.0871999999999997, (4, 9): 13.5923, (5, 1): 10.3587, (5, 2): 2.7176, (5, 3): 22.2155, (5, 4): 11.3604, (5, 5): 20.4867, (5, 6): 11.3892, (5, 7): 20.7407, (5, 8): 18.9028, (5, 9): 8.6505, (6, 1): 10.765600000000001, (6, 2): 9.983799999999999, (6, 3): 14.1591, (6, 4): 10.6896, (6, 5): 12.566, (6, 6): 6.4637, (6, 7): 15.5208, (6, 8): 10.8464, (6, 9): 4.7743, (7, 1): 14.2186, (7, 2): 9.6328, (7, 3): 19.874299999999998, (7, 4): 14.1426, (7, 5): 18.1455, (7, 6): 10.9415, (7, 7): 13.4544, (7, 8): 16.5615, (7, 9): 4.164, (8, 1): 13.0405, (8, 2): 13.8185, (8, 3): 12.5092, (8, 4): 12.9644, (8, 5): 10.9162, (8, 6): 8.7142, (8, 7): 14.452399999999999, (8, 8): 9.1965, (8, 9): 6.3978, (9, 1): 19.3733, (9, 2): 22.8555, (9, 3): 1.184, (9, 4): 19.2972, (9, 5): 9.023299999999999, (9, 6): 15.0471, (9, 7): 16.5285, (9, 8): 6.8957, (9, 9): 15.511700000000001, (10, 1): 16.4054, (10, 2): 11.321399999999999, (10, 3): 30.098, (10, 4): 18.0686, (10, 5): 28.3693, (10, 6): 21.1653, (10, 7): 22.6617, (10, 8): 26.7853, (10, 9): 14.387799999999999, (11, 1): 15.742, (11, 2): 13.1433, (11, 3): 12.027899999999999, (11, 4): 15.665899999999999, (11, 5): 10.4348, (11, 6): 10.870299999999999, (11, 7): 13.971, (11, 8): 8.715200000000001, (11, 9): 5.722600000000001, (12, 1): 12.4192, (12, 2): 5.826, (12, 3): 24.7506, (12, 4): 14.0823, (12, 5): 23.021900000000002, (12, 6): 16.2762, (12, 7): 18.4692, (12, 8): 21.437900000000003, (12, 9): 12.3013}

# %%
# Resolver el modelo usando un solver disponible (por ejemplo, GLPK)
solver = SolverFactory('glpk')
solver.solve(model)

# Verificar los resultados
for v in model.V:
    for c in model.C:
        for d in model.D:
            if model.x[d, c, v].value is not None and model.x[d, c, v].value > 0.5:
                print(f"Vehículo {v} asignado al cliente {c} desde el centro de distribución {d}")

# %%
import matplotlib.pyplot as plt

# Crear un mapa interactivo con Folium
m = folium.Map(location=[depots['Latitude'].mean(), depots['Longitude'].mean()], zoom_start=12)

# Agregar los centros de distribución y clientes al mapa
for _, depot in depots.iterrows():
    folium.Marker([depot['Latitude'], depot['Longitude']], popup=f"Centro: {depot['DepotID']}").add_to(m)

for _, client in clients.iterrows():
    folium.Marker([client['Latitude'], client['Longitude']], popup=f"Cliente: {client['ClientID']}").add_to(m)

# Mostrar el mapa
m.save('resultados/mapa_caso_2.html')

# %% [markdown]
# ## **Caso 3: Escenario Realista**
